-- %% [markdown]
-- Zadania na lab 1 Michał Szczurek

-- %% [markdown]
-- 4) Proste funkcje jednej zmiennej

-- %%
--1. Zdefiniować funkcję obliczającą długość wektora w 3D
vec3DLen :: (Double, Double, Double) -> Double
vec3DLen (x,y,z) = sqrt(x^2 + y^2 + z^2)

--2. Zdefiniować funkcję swap
swap :: (Int, Char) -> (Char, Int)
swap (a,b) = (b,a)

--3. Zdefiniować funkcję sprawdzającą, czy przekazane trzy liczby całkowite są równe
threeEqual :: (Int, Int, Int) -> Bool
threeEqual (x, y, z) =  (x == y) && (y == z)

-- %% [markdown]
-- 5) Definicje funkcji: wyrażenie warunkowe if...then...else

-- %%
--1. Używając if...else zdefiniować funkcję obliczającą wartość bezwzględną liczby całkowitej
absInt :: Int -> Int
absInt x = if x < 0
             then -x 
             else x

--2. Używając if...else zdefiniować funkcję
min2Int :: (Int, Int) -> Int 
min2Int (x,y) = if x < y
                then x
                else y
                
--5. (opcjonalne) Zdefiniować funkcje
toUpper :: Char -> Char
toUpper x = if fromEnum x <= 122 && fromEnum x >= 97
            then toEnum(fromEnum x -32)
            else x
            
toLower :: Char -> Char
toLower x = if fromEnum x <= 90 && fromEnum x >= 65
            then toEnum(fromEnum x +32)
            else x

-- %% [markdown]
-- 6) Definicje funkcji: guards

-- %%
--1. Używając "guards" zdefiniować funkcje
sgn :: Int -> Int
sgn x   | x < 0 = -1
        | x == 0 = 0
        | otherwise = 1

min3Int :: (Int, Int, Int) -> Int 
min3Int (x, y, z)   | (x < y) && (x < z) = x
                    | (y < x) && (y < z) = y
                    | otherwise = z
--2 Opcjonalne
toUpper :: Char -> Char
toUpper x   |fromEnum x <= 122 && fromEnum x >= 97 = toEnum(fromEnum x -32)
            |otherwise = x
-- Out:
-- 'A'

-- %% [markdown]
-- 7) Definicje funkcji: dopasowanie wzorców

-- %%
--1. Wykorzystując dopasowanie wzorców napisać definicje następujących funkcji logicznych
or' :: (Bool, Bool) -> Bool
or' (True,True) = True 
or' (True,False) = True 
or' (False,True) = True 
or' (False, False) = False

and' :: (Bool, Bool) -> Bool
and' (True,True) = True 
and' (True,False) = False 
and' (False,True) = False 
--komentarz do zad 10.2
and' (False, False) = False

nand' :: (Bool, Bool) -> Bool
nand' (True,True) = False
nand' (True,False) = True 
nand' (False,True) = True 
nand' (False, False) = True

xor' :: (Bool, Bool) -> Bool
xor' (True,True) = False 
xor' (True,False) = True 
xor' (False,True) = True 
xor' (False, False) = False

-- %% [markdown]
-- 8) Definicje funkcji: wyrażenie case...of

-- %%
--1. Wykorzystując case...of napisać definicje funkcji
or' :: (Bool, Bool) -> Bool
or' (x,y) = case (x,y) of
            (False, False) -> False
            _              -> True

and' :: (Bool, Bool) -> Bool
and' (x,y) = case (x,y) of
            (True,True) -> True
            _           -> False
            
nand' :: (Bool, Bool) -> Bool
nand' (x,y) = case (x,y) of
            (True, True) -> False
            _            -> True
            
xor' :: (Bool, Bool) -> Bool
xor' (x,y) = case (x,y) of 
           (False, True) -> True
           (True, False) -> True
           _             -> False

-- %% [markdown]
-- 9) Definicje lokalne: klauzula where

-- %%
--1. Wykorzystując klauzulę where napisać definicję funkcji obliczającą wersor (wektor jednostkowy) podanego jako argument wektora 2D
unitVec2D :: (Double, Double) -> (Double, Double)
unitVec2D (x,y) = (x/len, y/len)
            where len = sqrt(x^2 + y^2)
            
--2. (opcjonalne) Napisać definicję funkcji unitVec3D
unitVec3D :: (Double, Double, Double) -> (Double, Double, Double)
unitVec3D (x,y,z) = (x/len, y/len,z/len)
{- wieloliniowy 
 komentarz do zadania
 10.2-}
            where len = sqrt(x^2 + y^2 + z^2)

-- %% [markdown]
-- 10) Definicje lokalne: wyrażenie let...in

-- %%
--1. Przepisać rozwiązania zadań z poprzedniego punktu zamieniając where na let...in
unitVec2D :: (Double, Double) -> (Double, Double)
unitVec2D (x,y) = 
    -- komentarz do zadania 10.2
    let len = sqrt(x^2 + y^2)
    in (x/len, y/len)
            

unitVec3D :: (Double, Double, Double) -> (Double, Double, Double)
unitVec3D (x,y,z) = 
    let len = sqrt(x^2 + y^2 + z^2)
    in (x/len, y/len,z/len)
    
heron :: (Double, Double, Double) -> Double
heron (x,y,z) = 
    let p = (x + y + z)/2
    in sqrt(p*(p-x)*(p-y)*(p-z))

-- %% [markdown]
-- 11) Formatowanie kodu: off-side rule

-- %%
--1. Zmodyfikować klauzulę where w funkcji roots używając nawiasów {} do definicji granic bloku
roots :: (Double, Double, Double) -> (Double, Double)
roots (a, b, c) = ( (-b - d) / e, (-b + d) / e )
   where { d = sqrt (b * b - 4 * a * c);
       e = 2 * a;
       }
--2. Dodać w wybranych (poprzednio utworzonych) plikach komentarze (jedno i wieloliniowe)
-- komentarze są w zadaniach 10.1, 9.2, 7.1

-- %% [markdown]
-- 12) Polimorfizm i inferencja typów

-- %%
--1. Napisać kilka (-naście?) definicji funkcji (bez jawnego podawania typu, jak powyżej) za każdym razem zgadując wynik wnioskowania typów

let f1 x = x^2
:type f1

let f2 (x,y,z) = x^y + z
:type f2

let f3 x = case x of
         0     -> True
         _     -> False

:type f3

let f4 (x,y) | x > y = "wieszy"
             | x < y = "mniejszy"
             | otherwise = "równe"
:type f4

let f5 x = toEnum(x)
:type f5

let f6 (x,y,z) = (x*y,z)
:type f6

let f7 (x,y,z) = ("napis",x,z)
:type f7
-- Out:
-- f1 :: forall a. Num a => a -> a
-- f2 :: forall b a. (Integral b, Num a) => (a, b, a) -> a
-- f3 :: forall a. (Eq a, Num a) => a -> Bool
-- f4 :: forall a. Ord a => (a, a) -> [Char]
-- f5 :: forall a. Enum a => Int -> a
-- f6 :: forall a b. Num a => (a, a, b) -> (a, b)
-- f7 :: forall b1 b2 c. (b1, b2, c) -> ([Char], b1, c)
